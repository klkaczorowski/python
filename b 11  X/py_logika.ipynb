# %% [markdown]
# ![image.png](attachment:image.png)

# %%
True

# %%
False

# %%
type(True)

# %%
type(False)

# %%
True + 1 # True jest kodowane jako liczba 1

# %%
False - 2 # False jest kodowane jako liczba 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5 == 5

# %%
5 == 8

# %%
5 !=  5

# %%
5 != 8

# %%
4 < 7

# %%
4 > 7

# %%
4 <= 4

# %%
6 >= 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
6 == 6 and 7 == 7

# %%
True and True

# %%
True and False

# %%
5 == 5 and 5 != 5

# %%
False and True

# %%
5 != 5 and 5 == 5

# %%
False and False

# %%
4 == 5 and 6 == 7

# %%
4 < 7 < 8   # tak naprawdę dwa człony koniunkcji patrz poniżej

# %%
4 < 7 and 7 < 8

# %%
True or True

# %%
True or False

# %%
False or False

# %%
False or True

# %%
3 == 3 or 8 == 8

# %%
8 == 8 or 8 != 8

# %%
8 != 8 or 8 == 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1 == 1 and 2 < 7 and 3 > 1 and 6 != 66   # koniukcja wieloczłonowa

# %%
1 != 1 or 2 < 7 or 3 > 1 or 6 == 66  # alternatywa wieloczłonowa

# %% [markdown]
# # wczesne ustalanie wyniku

# %%
1 != 1 and (5/0) == 1   # ponieważ 1szy człon koniunkcji jest fałszem, to drugi jest pomijany

# %%
(5/0) == 1 and 1 != 1   # 1szy od lewej zawiera błąd

# %%
5 == 5 or 1 == (5/0)   # pierwszy człon alternatywy daje True, drugi człon jest pomijany

# %%
1 == (5/0)  or 5 == 5  # 1szy od lewej zawiera błąd

# %% [markdown]
# # not

# %%
not True

# %%
not False

# %%
not (5 ==5)

# %% [markdown]
# # kolejność operacji

# %%
a,b,c = 7, 4, 7

# %%
a == c

# %%
a == c and b == 4

# %%
a == 7 or b == 4 and c != 7

# %%
(a == 7 or b == 4) and c != 7

# %%
2 or 3  # or zwraca wartość po lewej lub prawej stronie operatora

# %%
0 or 3  # 0 fałsz

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
3 or 0 # prawda or fałsz daje fałsz

# %%
0 or 4 - 4  # 0 or 0 daje zero

# %%
4 and 5 # prawda and prawda daje prawdę

# %%
0 and 5   # fałsz and prawda daje prawdę

# %%
5 and 0

# %%
[] and True

# %%
[] or True

# %%
not 2
