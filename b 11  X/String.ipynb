# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'tutaj mamy łańcuch znaków'

# %%
"i jeszcze tu"

# %%
'powiedział "Co macie do zjedzenia"'

# %%
" ale to już nie przejdzie '   # sygnalizacjia błędu

# %%
# print("ale to się nie wykona")

# %%
print(" można # umieścić w napisie")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'jednalinia\ndrugalinia'# znak nowej linii

# %%
print('jednalinia\ndrugalinia') # znak nowej linii

# %%
print("tytuł \"Ogniem i mieczem\"")  #można używać znaku \ jak ktoś się uprze

# %%
print(r'jednalinia\ndrugalinia')  # raw-string czyli surowy tekst - sekwencje specjalne są ignorowane

# %%
print("Uczelnia\tSGH")

# %%
print("Uczelnia \b SGH")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"Wars" + 'zawa'  # konkatenacja

# %%
"Ali" "baba"   #spacja też konkatenacja, ale tylko dla napisów

# %%
"Macium Panie, " * 3  # powtarzanie

# %%
# wybranie pojedyńczego znaku z łańcucha: wynikiem jest jednoznakowy łańcuch znaków

# %%
'Warszawa'[0]

# %%
'Warszawa'[1]

# %%
'Warszawa'[-1]

# %%
'Warszawa'[-2]

# %%
# operacja pobierania fragmentu napisu (wycinanie) wynikiem jest nowy łańcuch znaków

# %%
'Warszawa'[2:5]

# %%
'Warszawa'[:3]

# %%
'Warszawa'[3:]

# %%
'Warszawa'[-3:-1]

# %%
'Warszawa'[:-2]

# %%
'Warszawa'[-2:]

# %%
'Warszawa'[:]  # ale to już kopia, inny łańcuch znaków

# %%
'Warszawa'[:5] + 'o' + 'Warszawa'[6:]      # Warszowa

# %%
'mark'[::-1]   # odwracanie łańcucha znaków

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
len('Warszawa')

# %% [markdown]
# ![image.png](attachment:19ca25f4-1d17-467a-9966-fb0ee2bc6e9f.png)

# %%
'Warszawa'.find('aw')  # zwraca indeks pierwszego wystąpienia wzorca

# %%
'Warszawa'.replace('a','o')   # zamiana każdego wystąpienia 'a' na 'o'

# %%
'Moja Warszawo'.split(' ')   # podział napisu: znakiem rozdzielającym jest spacja

# %%
'Warszawa'.upper()    # zamiana na wielkie znaki

# %%
'Warszawa'.lower()  # zamiana na małe znaki

# %%
'  Warszawa  '.rstrip()    # usuwamy poprzedzające spacje

# %%
'  Warszawa  '.lstrip()    # usuwamy końcowe spacje

# %%
'  Warszawa  '.strip()     # usuwamy poprzedzające i końcowe spacje spacje

# %%
'Warszawa'.isupper()       # nie wszystkie litery są wielkie

# %%
'Warszawa'.islower()       # nie wszystkie litery są małe

# %%
'WARSZAWA'.isupper()       # wszystkie litery są wielkie

# %%
'warszawa'.islower()       # wszystkie litery są małe

# %%
'wars&sawa'.islower()      # wszystkie litery są małe

# %%
'345'.isupper()           # brak wielkich liter
